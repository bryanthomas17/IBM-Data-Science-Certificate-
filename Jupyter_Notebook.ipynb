# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Final Assignment

# %% [markdown]
# This notebook is part of the final project for the IBM Data Science certificate.

# %% [markdown]
# Some of the popular data science languages are R, Python, and SQL.

# %% [markdown]
# Some of the popular data science libraries are Pandas, NumPy, and Matplotlib.

# %% [markdown]
# Here is a table of some commonly used Data Science tools:
#
# | Tool            | Description                |
# |-----------------|----------------------------|
# | Jupyter Notebook| Interactive coding and documentation |
# | RStudio         | IDE for R programming      |
# | Apache Spark    | Big data processing engine |

# %% [markdown]
# Below are some examples of simple arithmetic expressions in Python:
#
# - **Addition:** `3 + 5 = 8`
# - **Subtraction:** `10 - 4 = 6`
# - **Multiplication:** `7 * 6 = 42`

# %%
(3 * 4) + 5
# Out:
# 17

# %%
# 1 hour is 60 minutes
# we will convert 120 minutes to hours
120/60
# Out:
# 2.0

# %% [markdown]
# The objectives are:
#
# - Create and format Markdown cells
# - Create and execute Python code cells
# - Perform basic arithmetic operations
# - Convert values (e.g., minutes to hours)
# - Use Jupyter Notebook to organize work

# %% [markdown]
# Bryan Thomas
